# %% [markdown]
# # Worksheet-1

# %% [markdown]
# Introduction to Python Imaging Library(PIL)
# 2.1 Exercise - 1:
# Complete all the Task.
# 1. Read and display the image.
# • Read the image using the Pillow library and display it.
# • You can also use matplotlib to display the image.

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Replace with the actual path to your image
image_path = '/content/drive/MyDrive/Artificial intelligence and Machine learning/unnamed-2.png'

# Open the image using Pillow
image = Image.open(image_path)

# Display the image using Pillow
display(image)

# Optionally, display the image using matplotlib
# plt.imshow(image)
# plt.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=366x357>

# %% [markdown]
# 2. Display only the top left corner of 100x100 pixels.
# • Extract the top-left corner of the image (100x100 pixels) and display it using NumPy and
# Array Indexing.

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Replace with the actual path to your image
image_path = '/content/drive/MyDrive/Artificial intelligence and Machine learning/unnamed-2.png'

# Open the image using Pillow
image = Image.open(image_path)

# Crop the image to the top left corner (100x100 pixels)
cropped_image = image.crop(box=(0, 0, 100, 100))

# Display the cropped image
display(cropped_image)

# Optionally, display the image using matplotlib
# plt.imshow(cropped_image)
# plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Replace with the actual path to your image
image_path = '/content/drive/MyDrive/Artificial intelligence and Machine learning/unnamed-2.png'

# Open the image using Pillow
image = Image.open(image_path)

# Convert the image to a NumPy array
image_np = np.array(image)

# Extract the top-left corner (100x100 pixels) using array indexing
top_left_corner = image_np[0:100, 0:100]

# Display the top-left corner using matplotlib
plt.imshow(top_left_corner)
plt.show()

# %% [markdown]
# 3. Show the three color channels (R, G, B).
# • Separate the image into its three color channels (Red, Green, and Blue) and display them
# individually, labeling each channel as R, G, and B.{Using NumPy.}

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Load the image
image = Image.open('/content/drive/MyDrive/Artificial intelligence and Machine learning/unnamed-2.png')  # Replace with your image path
image_np = np.array(image)

# Separate color channels
red_channel = image_np[:, :, 0]  # Red channel (index 0)
green_channel = image_np[:, :, 1]  # Green channel (index 1)
blue_channel = image_np[:, :, 2]  # Blue channel (index 2)

# Display individual channels
plt.figure(figsize=(12, 4))

plt.subplot(131)
plt.imshow(red_channel, cmap='gray')
plt.title('Red Channel')

plt.subplot(132)
plt.imshow(green_channel, cmap='gray')
plt.title('Green Channel')

plt.subplot(133)
plt.imshow(blue_channel, cmap='gray')
plt.title('Blue Channel')

plt.show()

# %% [markdown]
# 4. Modify the top 100 × 100 pixels to a value of 210 and display the resulting image:
# • Modify the pixel values of the top-left 100 × 100 region to have a value of 210 (which is a
# light gray color), and then display the modified image.

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt


image_path = '/content/drive/MyDrive/Artificial intelligence and Machine learning/unnamed-2.png'

# Open the image using Pillow
image = Image.open(image_path)

# Convert the image to a NumPy array
image_np = np.array(image)

# Modify the top-left 100x100 pixels to 210
image_np[0:100, 0:100] = 210

# Create a PIL Image from the modified NumPy array
modified_image = Image.fromarray(image_np)

# Display the modified image
display(modified_image)

# Optionally, display the image using matplotlib
# plt.imshow(modified_image)
# plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=366x357>

# %% [markdown]
# # Exercise - 2:
# # Complete all the Task.

# %% [markdown]
# 1. Load and display a grayscale image.
# • Load a grayscale image using the Pillow library.

# %%
from PIL import Image


image_path = '/content/drive/MyDrive/Artificial intelligence and Machine learning/unnamed-2.png'

# Open the image in grayscale mode
image = Image.open(image_path).convert('L')

# Display the image
display(image)
# Out:
# <PIL.Image.Image image mode=L size=366x357>

# %% [markdown]
# Display the grayscale image using matplotlib.

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Replace with the actual path to your grayscale image
image_path = '/content/drive/MyDrive/Artificial intelligence and Machine learning/unnamed-2.png'

# Open the image in grayscale mode using Pillow
image = Image.open(image_path).convert('L')

# Display the image using matplotlib
plt.imshow(image, cmap='gray')  # cmap='gray' is important for grayscale
plt.show()

# %% [markdown]
# 2. Extract and display the middle section of the image (150 pixels).
# • Extract a 150 pixel section from the center of the image using NumPy array slicing.

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Replace with the actual path to your image
image_path = '/content/drive/MyDrive/Artificial intelligence and Machine learning/unnamed-2.png'

# Open the image using Pillow
image = Image.open(image_path).convert('L')  # Convert to grayscale

# Convert the image to a NumPy array
image_np = np.array(image)

# Get image dimensions
height, width = image_np.shape

# Calculate center coordinates and slice boundaries
center_y = height // 2
center_x = width // 2
start_y = center_y - 75  # 75 pixels above center
end_y = center_y + 75    # 75 pixels below center
start_x = center_x - 75  # 75 pixels left of center
end_x = center_x + 75    # 75 pixels right of center

# Extract the middle section using array slicing
middle_section = image_np[start_y:end_y, start_x:end_x]

# Display the middle section using matplotlib
plt.imshow(middle_section, cmap='gray')
plt.title('Middle Section (150x150 pixels)')
plt.show()

# %% [markdown]
# Display this cropped image using matplotlib.

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Replace with the actual path to your image
image_path = '/content/drive/MyDrive/Artificial intelligence and Machine learning/unnamed-2.png'

# Open the image using Pillow
image = Image.open(image_path).convert('L')  # Convert to grayscale

# Convert the image to a NumPy array
image_np = np.array(image)

# ... (Code to extract the middle section as before) ...

# Display the cropped image using matplotlib
plt.imshow(middle_section, cmap='gray')  # Use cmap='gray' for grayscale
plt.title('Cropped Image (Middle Section)')
plt.show()

# %% [markdown]
# Apply a simple threshold to the image (e.g., set all pixel values below 100 to 0).
# • Apply a threshold to the grayscale image: set all pixel values below 100 to 0, and all values
# above 100 to 255 (creating a binary image).
# Display the resulting binary image.

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Replace with the actual path to your image
image_path = '/content/drive/MyDrive/Artificial intelligence and Machine learning/unnamed-2.png'

# Open the image using Pillow and convert to grayscale
image = Image.open(image_path).convert('L')

# Convert the image to a NumPy array
image_np = np.array(image)

# Apply threshold
threshold_value = 100
binary_image_np = np.where(image_np < threshold_value, 0, 255)

# Convert back to PIL Image
binary_image = Image.fromarray(binary_image_np.astype(np.uint8))

# Display the binary image
plt.imshow(binary_image, cmap='gray')
plt.title('Binary Image (Threshold = 100)')
plt.show()

# %% [markdown]
# Rotate the image 90 degrees clockwise and display the result.
# • Rotate the image by 90 degrees clockwise using the Pillow rotate method or by manipulating
# the image array.
# • Display the rotated image using matplotlib.

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Replace with the actual path to your image
image_path = '/content/drive/MyDrive/Artificial intelligence and Machine learning/unnamed-2.png'

# Open the image using Pillow
image = Image.open(image_path)

# Rotate the image 90 degrees clockwise
rotated_image = image.rotate(90, expand=True)  # expand=True to avoid cropping


# Display the rotated image using matplotlib
plt.imshow(rotated_image)
plt.title('Rotated Image (90 degrees clockwise)')
plt.show()

# %% [markdown]
# Convert the grayscale image to an RGB image.
# • Convert the grayscale image into an RGB image where the grayscale values are replicated
# across all three channels (R, G, and B).
# • Display the converted RGB image using matplotlib.

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Replace with the actual path to your grayscale image
image_path = '/content/drive/MyDrive/Artificial intelligence and Machine learning/unnamed-2.png'

# Open the image in grayscale mode
gray_image = Image.open(image_path).convert('L')

# Convert to RGB
rgb_image = gray_image.convert('RGB')

# Display the RGB image using matplotlib
plt.imshow(rgb_image)
plt.title('RGB Image (Converted from Grayscale)')
plt.show()

# %% [markdown]
# # Image Compression and Decompression using PCA.

# %% [markdown]
# 1. Load and Prepare Data:
# • Fetch an image of you choice.{If colour convert to grayscale}
# • Center the dataset - Standaridze the Data.
# • Calculate the covaraince matrix of the Standaridze data.

# %%
import numpy as np
from PIL import Image

# 1. Load and convert to grayscale
image_path = '/content/drive/MyDrive/Artificial intelligence and Machine learning/unnamed-2.png'
image = Image.open(image_path).convert('L')
image_np = np.array(image)

# 2. Center the dataset (Standardize the Data)
# Calculate mean and standard deviation
mean = np.mean(image_np)
std = np.std(image_np)

# Standardize the data
standardized_data = (image_np - mean) / std

# 3. Calculate the covariance matrix
covariance_matrix = np.cov(standardized_data, rowvar=False)

# Print or use the covariance matrix as needed
print(covariance_matrix)
# Out:
# [[ 0.63151995  0.61539384  0.59823939 ... -0.20317985 -0.19751555
#   -0.17746954]
#  [ 0.61539384  0.60940111  0.59593405 ... -0.23273413 -0.22640124
#   -0.20698558]
#  [ 0.59823939  0.59593405  0.59271171 ... -0.2476314  -0.24075542
#   -0.2222826 ]
#  ...
#  [-0.20317985 -0.23273413 -0.2476314  ...  1.3075225   1.29483298
#    1.28089899]
#  [-0.19751555 -0.22640124 -0.24075542 ...  1.29483298  1.29347978
#    1.28690391]
#  [-0.17746954 -0.20698558 -0.2222826  ...  1.28089899  1.28690391
#    1.2924409 ]]

# %% [markdown]
# Eigen Decomposition and Identifying Principal Components:
# • Compute Eigen Values and Eigen Vectors.
# • Sort the eigenvalues in descending order and choose the top k eigenvectors corresponding to
# the highest eigenvalues.
# • Identify the Principal Components with the help of cumulative Sum plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

# ... (Previous code to load and standardize data) ...

# 1. Compute Eigenvalues and Eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(covariance_matrix)

# 2. Sort Eigenvalues and Choose Top k Eigenvectors
k = 100  # Choose the number of principal components (k)
sorted_indices = np.argsort(eigenvalues)[::-1]  # Sort in descending order
top_k_eigenvectors = eigenvectors[:, sorted_indices[:k]]

# 3. Cumulative Sum Plot to Identify Principal Components
explained_variance = np.cumsum(eigenvalues[sorted_indices]) / np.sum(eigenvalues)
plt.plot(explained_variance)
plt.xlabel('Number of Principal Components (k)')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance vs. Number of Principal Components')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /usr/local/lib/python3.11/dist-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# Reconstruction and Experiment:
#
# • Reconstruction: Transform the original data by multiplying it with the selected eigenvec-
# tors(PCs) to obtain a lower-dimensional representation.
#
# • Experiments: Pick Four different combination of principal components with various ex-
# plained variance value and compare the result.
#
# • Display the Results and Evaluate.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# ... (Previous code to load, standardize data, and calculate eigenvectors) ...

def reconstruct_image(image_np, eigenvectors, k):
  """Reconstructs the image using the top k eigenvectors."""
  # Project the standardized data onto the top k eigenvectors
  projected_data = standardized_data.dot(eigenvectors[:, :k])

  # Reconstruct the image
  reconstructed_image = projected_data.dot(eigenvectors[:, :k].T) * std + mean
  reconstructed_image = reconstructed_image.astype(np.uint8)

  return reconstructed_image

# Experiment with different values of k
k_values = [10, 50, 100, 200]  # Example k values

# Display original and reconstructed images
plt.figure(figsize=(12, 6))
plt.subplot(2, 3, 1)
plt.imshow(image_np, cmap='gray')
plt.title('Original Image')

for i, k in enumerate(k_values):
    reconstructed_image = reconstruct_image(image_np, eigenvectors, k)
    plt.subplot(2, 3, i + 2)
    plt.imshow(reconstructed_image, cmap='gray')
    plt.title(f'Reconstructed (k={k})')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-23-2ac666695483>:14: ComplexWarning: Casting complex values to real discards the imaginary part
#   reconstructed_image = reconstructed_image.astype(np.uint8)
